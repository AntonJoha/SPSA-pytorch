# %%
# !pip install  torchao==0.10.0 transformers datasets

# %%
import torch
torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# device(type='cuda', index=0)

# %%
from train import run_spsa_experiments

lr_options = [1e-2, 1e-3]
scaling_options = [ 5e-2, 1e-3, 3e-4, 1e-4]

run_spsa_experiments(optimizer_name="spsa", lr_options=lr_options, scaling_options=scaling_options, epochs=4)
# Out:
# cuda:0
# 2026-04-21 06:30:19.923049: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776753019.937510    2959 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776753019.942152    2959 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-21 06:30:19.957634: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
