# %%
# !pip install  torchao==0.10.0 transformers datasets

# %%
import torch
torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# device(type='cuda', index=0)

# %%
from train import run_spsa_experiments

lr_options = [1e-3, 3e-4, 1e-4,1e-5,1e-6,1e-7]
scaling_options = [1e-1,1e-2,1e-3, 3e-4, 1e-4]


run_spsa_experiments(lr_options=lr_options, scaling_options=scaling_options, epochs=500)
# Out:
# cuda:0
# 2026-04-16 13:42:39.639444: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776346959.654350   18795 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776346959.659131   18795 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-16 13:42:39.675498: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
