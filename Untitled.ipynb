# %%
# !pip install  torchao==0.10.0 transformers datasets

# %%
import torch
torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
from bert_imdb_train import run_simple_bert_imdb

losses = run_simple_bert_imdb(
    batch_size=8,
    epochs=10,
    lr=3e-4,
    delta=1e-3,
    truncated_dataset=300,
    verbose=True,
)
